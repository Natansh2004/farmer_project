# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('farmer.csv')

# %%
df
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
df['label'].value_counts()
# Out:
# label
# rice           100
# maize          100
# jute           100
# cotton         100
# coconut        100
# papaya         100
# orange         100
# apple          100
# muskmelon      100
# watermelon     100
# grapes         100
# mango          100
# banana         100
# pomegranate    100
# lentil         100
# blackgram      100
# mungbean       100
# mothbeans      100
# pigeonpeas     100
# kidneybeans    100
# chickpea       100
# coffee         100
# Name: count, dtype: int64

# %%
group = df.groupby('label')

# %%
group

# %%
group.head()
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2100   91  21  26    26.333780  57.364700  7.261314  191.654941  coffee
# 2101  107  21  26    26.452885  55.322227  7.235070  144.686134  coffee
# 2102   83  38  35    25.708227  52.886671  7.189156  136.732509  coffee
# 2103  108  24  31    24.128325  56.181077  6.431900  147.275782  coffee
# 2104  116  28  34    23.443723  60.395233  6.423211  122.210325  coffee
#
# [110 rows x 8 columns]

# %%
group[['temperature']].mean()
# Out:
#              temperature
# label
# apple          22.630942
# banana         27.376798
# blackgram      29.973340
# chickpea       18.872847
# coconut        27.409892
# coffee         25.540477
# cotton         23.988958
# grapes         23.849575
# jute           24.958376
# kidneybeans    20.115085
# lentil         24.509052
# maize          22.389204
# mango          31.208770
# mothbeans      28.194920
# mungbean       28.525775
# muskmelon      28.663066
# orange         22.765725
# papaya         33.723859
# pigeonpeas     27.741762
# pomegranate    21.837842
# rice           23.689332
# watermelon     25.591767

# %%
## UNSUPERVISED LEARNING ALGORITHM

# It performs clustering analysis
# Clustering analysis groups the data based on the similarity 
# In unsupervised learning, only x_variables are there...

# group will only be performed when all the factors are similar

# %%
# Calculating mean, min, and max all together
result = group[['temperature']].agg(['mean','min','max'])
result
# Out:
#             temperature
#                    mean        min        max
# label
# apple         22.630942  21.036527  23.996862
# banana        27.376798  25.010185  29.908885
# blackgram     29.973340  25.097374  34.946616
# chickpea      18.872847  17.024985  20.995022
# coconut       27.409892  25.008724  29.869083
# coffee        25.540477  23.059519  27.923744
# cotton        23.988958  22.000851  25.992374
# grapes        23.849575   8.825675  41.948657
# jute          24.958376  23.094338  26.985822
# kidneybeans   20.115085  15.330426  24.923601
# lentil        24.509052  18.064861  29.944139
# maize         22.389204  18.041855  26.549864
# mango         31.208770  27.003155  35.990097
# mothbeans     28.194920  24.018254  31.999286
# mungbean      28.525775  27.014704  29.914544
# muskmelon     28.663066  27.024151  29.943492
# orange        22.765725  10.010813  34.906653
# papaya        33.723859  23.012402  43.675493
# pigeonpeas    27.741762  18.319104  36.977944
# ...

# %%
result.index
# Out:
# Index(['apple', 'banana', 'blackgram', 'chickpea', 'coconut', 'coffee',
#        'cotton', 'grapes', 'jute', 'kidneybeans', 'lentil', 'maize', 'mango',
#        'mothbeans', 'mungbean', 'muskmelon', 'orange', 'papaya', 'pigeonpeas',
#        'pomegranate', 'rice', 'watermelon'],
#       dtype='object', name='label')

# %%
result.reset_index(inplace=True)

# %%
result
# Out:
#           label temperature
#                        mean        min        max
# 0         apple   22.630942  21.036527  23.996862
# 1        banana   27.376798  25.010185  29.908885
# 2     blackgram   29.973340  25.097374  34.946616
# 3      chickpea   18.872847  17.024985  20.995022
# 4       coconut   27.409892  25.008724  29.869083
# 5        coffee   25.540477  23.059519  27.923744
# 6        cotton   23.988958  22.000851  25.992374
# 7        grapes   23.849575   8.825675  41.948657
# 8          jute   24.958376  23.094338  26.985822
# 9   kidneybeans   20.115085  15.330426  24.923601
# 10       lentil   24.509052  18.064861  29.944139
# 11        maize   22.389204  18.041855  26.549864
# 12        mango   31.208770  27.003155  35.990097
# 13    mothbeans   28.194920  24.018254  31.999286
# 14     mungbean   28.525775  27.014704  29.914544
# 15    muskmelon   28.663066  27.024151  29.943492
# 16       orange   22.765725  10.010813  34.906653
# ...

# %%
mean_temperature = group['temperature'].mean()
mean_temperature.plot.bar(color='crimson')

plt.xlabel('Label')
plt.ylabel('Avg Temperature')
plt.title('Avg Temperature by Label')

plt.show()

# %%
mean_temperature
# Out:
# label
# apple          22.630942
# banana         27.376798
# blackgram      29.973340
# chickpea       18.872847
# coconut        27.409892
# coffee         25.540477
# cotton         23.988958
# grapes         23.849575
# jute           24.958376
# kidneybeans    20.115085
# lentil         24.509052
# maize          22.389204
# mango          31.208770
# mothbeans      28.194920
# mungbean       28.525775
# muskmelon      28.663066
# orange         22.765725
# papaya         33.723859
# pigeonpeas     27.741762
# pomegranate    21.837842
# rice           23.689332
# watermelon     25.591767
# Name: temperature, dtype: float64

# %%
type(mean_temperature)
# Out:
# pandas.core.series.Series

# %%
min_temperature = group['temperature'].min()
min_temperature.plot.bar(color='crimson')

plt.xlabel('Label')
plt.ylabel('Min Temperature')
plt.title('Min Temperature by Label')

plt.show()

# %%
max_temperature = group['temperature'].max()
max_temperature.plot.bar(color='crimson')

plt.xlabel('Label')
plt.ylabel('Max Temperature')
plt.title('Max Temperature by Label')

plt.show()

# %%
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
# Removing 'y' label
x = df.drop('label',axis='columns')
x.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340

# %%
# checking missing values
x.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# dtype: int64

# %%
df.info()   # we need to check this before
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %%
df.shape
# Out:
# (2200, 8)

# %%
x.duplicated().sum()
# Out:
# 0

# %%
x

# no categorical column
# Out:
#         N   P   K  temperature   humidity        ph    rainfall
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340
# ...   ...  ..  ..          ...        ...       ...         ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041
#
# [2200 rows x 7 columns]

# %%
x.dtypes
# Out:
# N                int64
# P                int64
# K                int64
# temperature    float64
# humidity       float64
# ph             float64
# rainfall       float64
# dtype: object

# %%
# kernel density estimator plot (kde plot)
# to checkout the distribution of the data

sns.kdeplot(x['temperature'])
# Out:
# <Axes: xlabel='temperature', ylabel='Density'>

# %%
x.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340

# %%
# Data transformation
# scaling down the data (in a range)
# to remove all the outliers 

from sklearn.preprocessing import StandardScaler

# %%
std_scaler = StandardScaler()
x_transformed = std_scaler.fit_transform(x)  
# fit_transform()--> fit as well as tranform the data
x_transformed

# std_scaler uses z_score formula behind the scenes
# Out:
# array([[ 1.0687974 , -0.34455075, -0.1016875 , ...,  0.47266646,
#          0.04330173,  1.8103605 ],
#        [ 0.93332887,  0.14061552, -0.14118477, ...,  0.39705125,
#          0.73487256,  2.24205791],
#        [ 0.25598625,  0.04964684, -0.08193887, ...,  0.48695381,
#          1.77151047,  2.92106603],
#        ...,
#        [ 1.82742114, -0.61745677, -0.35841972, ..., -0.19123516,
#         -0.13812031,  1.27141766],
#        [ 1.80032743, -0.64777967, -0.27942519, ..., -0.86951801,
#          0.37390383,  0.43154519],
#        [ 1.44810927, -1.07230015, -0.35841972, ..., -0.49802006,
#          0.40109573,  0.68200518]])

# %%
x_transformed.shape
# Out:
# (2200, 7)

# %%
x.shape
# Out:
# (2200, 7)

# %%
# we have just scaled down the data, nothing else

# %%
pd.DataFrame(x_transformed)
# Out:
#              0         1         2         3         4         5         6
# 0     1.068797 -0.344551 -0.101688 -0.935587  0.472666  0.043302  1.810361
# 1     0.933329  0.140616 -0.141185 -0.759646  0.397051  0.734873  2.242058
# 2     0.255986  0.049647 -0.081939 -0.515898  0.486954  1.771510  2.921066
# 3     0.635298 -0.556811 -0.160933  0.172807  0.389805  0.660308  2.537048
# 4     0.743673 -0.344551 -0.121436 -1.083647  0.454792  1.497868  2.898373
# ...        ...       ...       ...       ...       ...       ...       ...
# 2195  1.529390 -0.587134 -0.318922  0.228814 -0.227709  0.401395  1.352437
# 2196  1.312641 -1.163269 -0.417666  0.355720 -0.666947 -0.494413  0.445183
# 2197  1.827421 -0.617457 -0.358420 -0.293218 -0.191235 -0.138120  1.271418
# 2198  1.800327 -0.647780 -0.279425  0.129612 -0.869518  0.373904  0.431545
# 2199  1.448109 -1.072300 -0.358420 -0.397667 -0.498020  0.401096  0.682005
#
# [2200 rows x 7 columns]

# %%
pd.DataFrame(x_transformed)[3]

# temperature column
# Out:
# 0      -0.935587
# 1      -0.759646
# 2      -0.515898
# 3       0.172807
# 4      -1.083647
#           ...
# 2195    0.228814
# 2196    0.355720
# 2197   -0.293218
# 2198    0.129612
# 2199   -0.397667
# Name: 3, Length: 2200, dtype: float64

# %%
sns.kdeplot(pd.DataFrame(x_transformed)[3])
plt.show()

# scaled down data

# %%
sns.kdeplot(x['temperature'])
plt.show()

# without scaled down data

# %%
# we've scaled down the data but still both the graphs are exactly same
# distribution of both the graphs are similar
# just we have scaled down the data into a another form
# outliers will be hidden
# the meaning of the data is retained

# k_means algorithm is such an algorithm that demands outliers-free data

# if we do not scale down the data before passing this to 
# algorithm, then the accuracy will reduce

# and we will use this algorithm in this project

# %%
## NOW THE DATA IS READY TO TRAIN THE ALGORITHM

from sklearn.cluster import KMeans
# KMeans algorithm performs clustering analysis

# %%
kmeans_obj = KMeans()
kmeans_obj
# Out:
# KMeans()

# %%
labels = kmeans_obj.fit_predict(x_transformed)

# fit_predict ---> fit and predict both
# algorithm trained and predict

# %%
labels
# Out:
# array([5, 5, 5, ..., 1, 1, 1])

# %%
len(labels)
# Out:
# 2200

# %%
set(labels)

# these are group numbers
# set is an unique collection
# Out:
# {0, 1, 2, 3, 4, 5, 6, 7}

# %%
labels.shape
# Out:
# (2200,)

# %%
x_transformed.shape
# Out:
# (2200, 7)

# %%
df['cluster_no'] = labels

# %%
df.head(40)
# Out:
#      N   P   K  temperature   humidity        ph    rainfall label  cluster_no
# 0   90  42  43    20.879744  82.002744  6.502985  202.935536  rice           5
# 1   85  58  41    21.770462  80.319644  7.038096  226.655537  rice           5
# 2   60  55  44    23.004459  82.320763  7.840207  263.964248  rice           5
# 3   74  35  40    26.491096  80.158363  6.980401  242.864034  rice           5
# 4   78  42  42    20.130175  81.604873  7.628473  262.717340  rice           5
# 5   69  37  42    23.058049  83.370118  7.073454  251.055000  rice           5
# 6   69  55  38    22.708838  82.639414  5.700806  271.324860  rice           5
# 7   94  53  40    20.277744  82.894086  5.718627  241.974195  rice           5
# 8   89  54  38    24.515881  83.535216  6.685346  230.446236  rice           5
# 9   68  58  38    23.223974  83.033227  6.336254  221.209196  rice           5
# 10  91  53  40    26.527235  81.417538  5.386168  264.614870  rice           5
# ...

# %%
df[df['cluster_no']==7]
# Out:
#       N   P   K  temperature   humidity        ph   rainfall     label  \
# 115  63  58  22    18.254054  55.282204  6.204748  63.723582     maize
# 202  39  58  85    17.887765  15.405897  5.996932  68.549329  chickpea
# 205  32  73  81    20.450786  15.403121  5.988993  92.683737  chickpea
# 225  22  67  78    17.166064  14.424575  6.204091  72.326675  chickpea
# 226  36  65  80    18.287201  16.679216  6.051091  74.874456  chickpea
# ..   ..  ..  ..          ...        ...       ...        ...       ...
# 814  39  78  15    21.354995  62.601363  5.925392  41.782198    lentil
# 830  30  79  22    18.287661  69.485151  6.254217  48.604494    lentil
# 833  10  78  18    18.541418  62.706376  6.296977  44.078197    lentil
# 870  26  66  22    18.064861  65.103435  6.300479  51.549228    lentil
# 871  16  65  16    18.130278  62.458516  6.078724  50.612852    lentil
#
#      cluster_no
# 115           7
# 202           7
# 205           7
# 225           7
# 226           7
# ...

# %%
df[df['cluster_no']==7]['label']
# Out:
# 115       maize
# 202    chickpea
# 205    chickpea
# 225    chickpea
# 226    chickpea
#          ...
# 814      lentil
# 830      lentil
# 833      lentil
# 870      lentil
# 871      lentil
# Name: label, Length: 140, dtype: object

# %%
df[df['cluster_no']==7]['label'].unique()

# 7th group has all these crops based on similar requirements
# Out:
# array(['maize', 'chickpea', 'kidneybeans', 'pigeonpeas', 'lentil'],
#       dtype=object)

# %%
df[df['cluster_no']==6]['label'].unique()
# Out:
# array(['chickpea'], dtype=object)

# %%
import os,joblib
os.makedirs('models',exist_ok=True)
joblib.dump(std_scaler,'./models/std_scaler.lb')  
joblib.dump(kmeans_obj,'./models/kmeans_model.lb')

# std_scaler --> scaling down the data
# kmeans_obj --> performs clustering analysis
# Out:
# ['./models/kmeans_model.lb']

# %%
df[['label','cluster_no']]
# Out:
#        label  cluster_no
# 0       rice           5
# 1       rice           5
# 2       rice           5
# 3       rice           5
# 4       rice           5
# ...      ...         ...
# 2195  coffee           5
# 2196  coffee           1
# 2197  coffee           1
# 2198  coffee           1
# 2199  coffee           1
#
# [2200 rows x 2 columns]

# %%
df[['label','cluster_no']].to_csv('./models/filter_crops.csv',index=False)

# index=False means that do not save the index values
# file saved so that we can use in front end
